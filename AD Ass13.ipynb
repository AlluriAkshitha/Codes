# %%
# Assuming the column for product names is 'Product_Name'
plt.figure(figsize=(10, 6))
sns.lineplot(data=df, x='Trial_Period', y='Sales', hue='Product_Name', marker='o')
plt.title('Sales Trend for Each Product Over Different Trial Periods')
plt.xlabel('Trial Period')
plt.ylabel('Sales')
plt.legend(title='Product')
plt.show()
